# %%
import json_helper

# %%
df = json_helper.read_all_json_files('./data/daily_summaries')

# %%
df
# Out:
#      attributes datatype                 date            station  value  \
# 0          ,,N,     PRCP  2018-12-01T00:00:00  GHCND:US1DENC0001      0
# 1         T,,N,     PRCP  2018-12-01T00:00:00  GHCND:US1DENC0002      0
# 2          ,,N,     SNOW  2018-12-01T00:00:00  GHCND:US1DENC0002      0
# 3          ,,N,     SNWD  2018-12-01T00:00:00  GHCND:US1DENC0002      0
# 4          ,,N,     WESD  2018-12-01T00:00:00  GHCND:US1DENC0002      0
# ...         ...      ...                  ...                ...    ...
# 1267       ,,W,     WDF2  2018-12-31T00:00:00  GHCND:USW00013781    130
# 1268       ,,W,     WDF5  2018-12-31T00:00:00  GHCND:USW00013781    130
# 1269       ,,W,     WSF2  2018-12-31T00:00:00  GHCND:USW00013781     63
# 1270       ,,W,     WSF5  2018-12-31T00:00:00  GHCND:USW00013781     76
# 1271       ,,W,     WT01  2018-12-31T00:00:00  GHCND:USW00013781      1
#
#                                      file_name
# 0     daily_summaries_FIP10003_dec_2018_0.json
# 1     daily_summaries_FIP10003_dec_2018_0.json
# 2     daily_summaries_FIP10003_dec_2018_0.json
# 3     daily_summaries_FIP10003_dec_2018_0.json
# 4     daily_summaries_FIP10003_dec_2018_0.json
# ...                                        ...
# 1267  daily_summaries_FIP10003_dec_2018_1.json
# 1268  daily_summaries_FIP10003_dec_2018_1.json
# 1269  daily_summaries_FIP10003_dec_2018_1.json
# 1270  daily_summaries_FIP10003_dec_2018_1.json
# 1271  daily_summaries_FIP10003_dec_2018_1.json
#
# [1272 rows x 6 columns]

# %% [markdown]
# How many stations are there in total for FIPS10003

# %%
df.station.nunique()
# Out:
# 18

# %% [markdown]
# Create a DataFrame called temps_max that only contains the entries from df_daily_summaries where the datatype column is equal to TMAX. This DataFrame should only retain the date column and the value column.

# %%
df_tmax = df[df['datatype'] == 'TMAX']
temps_max = df_tmax[['date', 'value']]

# %%
temps_max
# Out:
#                      date  value
# 21    2018-12-01T00:00:00     61
# 29    2018-12-01T00:00:00     78
# 58    2018-12-02T00:00:00    128
# 66    2018-12-02T00:00:00    144
# 97    2018-12-03T00:00:00    122
# ...                   ...    ...
# 1182  2018-12-29T00:00:00    117
# 1217  2018-12-30T00:00:00     56
# 1225  2018-12-30T00:00:00     83
# 1257  2018-12-31T00:00:00     83
# 1265  2018-12-31T00:00:00     83
#
# [62 rows x 2 columns]

# %% [markdown]
# How many entries are there in the temps_max DataFrame? What are the mean, min, and max values?

# %%
temps_max.describe()
# Out:
#             value
# count   62.000000
# mean    76.822581
# std     40.593759
# min     -6.000000
# 25%     51.500000
# 50%     78.000000
# 75%    104.500000
# max    161.000000

# %% [markdown]
# Let's graph this DataFrame so we can get a visual representation for this information.

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x = temps_max['date'].str[8:10]
y = temps_max['value'] / 10

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, y)
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Max Temperatues Dec 2018')
# Out:
# [Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 0, 'day of month'),
#  Text(0.5, 1.0, 'Max Temperatues Dec 2018')]

# %% [markdown]
# Create a DataFrame called temps_min that only contains the entries from df_daily_summaries where the datatype column is equal to TMIN. This DataFrame should only retain the date column and the value column.

# %%
df_tmin = df[df['datatype'] == 'TMIN']
temps_min = df_tmin[['date', 'value']]

# %%
temps_min
# Out:
#                      date  value
# 22    2018-12-01T00:00:00     11
# 30    2018-12-01T00:00:00    -16
# 59    2018-12-02T00:00:00     50
# 67    2018-12-02T00:00:00     67
# 98    2018-12-03T00:00:00     50
# ...                   ...    ...
# 1183  2018-12-29T00:00:00     22
# 1218  2018-12-30T00:00:00      6
# 1226  2018-12-30T00:00:00     -5
# 1258  2018-12-31T00:00:00    -11
# 1266  2018-12-31T00:00:00    -10
#
# [62 rows x 2 columns]

# %% [markdown]
# How many entries are there in the temps_min DataFrame? What are the mean, min, and max values?

# %%
temps_min.describe()
# Out:
#            value
# count  62.000000
# mean   -3.903226
# std    39.676854
# min   -71.000000
# 25%   -32.750000
# 50%   -11.000000
# 75%    22.000000
# max    94.000000

# %% [markdown]
# Graph the temps_min DataFrame

# %%
x = temps_min['date'].str[8:10]
y = temps_min['value'] / 10

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, y)
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Min Temperatues Dec 2018')
# Out:
# [Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 0, 'day of month'),
#  Text(0.5, 1.0, 'Min Temperatues Dec 2018')]

# %% [markdown]
# We can also plot both of these lines in the same graph.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, temps_max['value'] / 10, color='red')
ax.plot(x, temps_min['value'] / 10, color='blue')
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Min & Max Temperatues Dec 2018')
# Out:
# [Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 0, 'day of month'),
#  Text(0.5, 1.0, 'Min & Max Temperatues Dec 2018')]
